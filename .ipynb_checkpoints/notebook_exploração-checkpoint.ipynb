# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns; sns.set()

from google.cloud.bigquery import Client, QueryJobConfig
client = Client()
query = """SELECT * FROM `hacka-dados.hacka_dados.tabela_dados_hacka`"""
job = client.query(query)
df = job.to_dataframe()

# %% [markdown]
# ## Limpeza
#
# #### Notação de células vazias

# %%
def uniform_missing_values(df, notacoes=['nan', '']):
    obj_cols = df.columns[df.dtypes=='object']
    for col in obj_cols:
        for value in notacoes:
            df[col] = df[col].replace(value, np.nan)
    return df

# %%
df = uniform_missing_values(df, notacoes=['nan', ''])

# Descomente para conferir valores diferentes para notações ou conferir substituição (se já foi feita).
# for col in obj_cols: print(f'{col}: {df[col].unique()}'); print()

# %% [markdown]
# #### Células vazias e nulas por coluna

# %%
empty = df.isna().sum().nlargest(df.shape[1]) / df.shape[0]
null = (df==0).sum().nlargest(df.shape[1]) / df.shape[0]

fig, ax = plt.subplots(figsize=(6, 3.5))
empty.plot()
null.loc[empty.index].plot() # descomente para incluir valores nulos
(empty+null.loc[empty.index]).plot() # descomente para incluir valores nulos
ax.set(
    xticks=[],
    xlabel='Colunas',
    ylabel='Células (%)',
    title='Células vazias e nulas por coluna (%)',
)
ax.legend(['Vazios (%)', 'Nulos (%)', 'Vazios+Nulos']); plt.show()

# %% [markdown]
# #### Células vazias e nulas por linha

# %%
empty = df.isna().sum(1).nlargest(df.shape[0]) / df.shape[1]
null = (df==0).sum(1).nlargest(df.shape[0]) / df.shape[1]

fig, ax = plt.subplots(figsize=(6, 3.5))
ax.plot(np.percentile(empty, range(100)))
ax.plot(np.percentile(null, range(100)))
ax.set(
    xticks=[],
    xlabel='Células (%)',
    ylabel='Linhas (%)',
    title='Percentil vazios/nulos por linha (%/%)',
)
ax.legend(['Vazios (%)', 'Nulos (%) - dentre não vazios'], loc='upper left'); plt.show()

# %% [markdown]
# ## Transformação de dados

# %%
data = df.copy() #; data = data[sel_cols]

# import preprocessing functions
from sklearn.preprocessing import LabelEncoder as le, MinMaxScaler as mms

# extract columns for each data type
int_cols, obj_cols, float_cols = (
    data.select_dtypes([datatype]).columns.tolist() for datatype in ('int64', 'object', 'float')
)

# fill missing values for float columns
# for col in float_cols:
    # data[col].fillna(data[col].mean(), inplace=True)
    # data[col].fillna(-1, inplace=True)

#### Scale Float Columns
data[float_cols] = mms().fit_transform(data[float_cols]) # eliminates negative values


#### Label Encode Categorical Columns
for col in obj_cols:
    # data[col].fillna((-1 if col in int_cols else '-1'), inplace=True)
    data[col] = le().fit_transform(data[col]) # fill missing values automatically

# %% [markdown]
# ### Exploração

# %%
target = 'fl_renovou'

msk = data[target] == 1
mino, majo = data[msk], data[msk==False] # Filtrando classes majoritária e minoritária

# %% [markdown]
# ##### Diferença percentual da média entre classes

# %%
prct_dif = ( data[float_cols].mean() - mino[float_cols].mean() ) / data[float_cols].mean()
abs_dif = abs(prct_dif.loc[abs(prct_dif).sort_values(ascending=False).index])

abs_dif.head(100).plot(
    xticks=[], marker='o', ms=4,
    xlabel='Colunas numéricas',
    ylabel='Diferença percentual (%)',
    title='Diferença percentual absoluta da média\nentre classes (Normalizado)'
); plt.show()

# plt.ylim((-.1,2))

# %%
col_rank = pd.Series(np.zeros(len(abs_dif))+1, index=abs_dif.index)
# bins = [2.5, 1, .75, .5, .25]
bins = [1, .75, .5, .25, .15]
for i, lim in enumerate(bins):
    col_rank.loc[abs_dif<lim] = i+2

col_rank.loc[abs_dif.isna()] = np.nan

# %%
cols = set(float_cols)
for i in range(1, len(bins)+2):
    a = abs_dif[col_rank==i].to_frame(f'Rank {i}')
    display(a)
# Out:
#                                   Rank 1
# total_ARTIGOS_ESPORTIVOS_F2_m4  1.530431
# NV_D2_OBJETIVIDADE_3m           1.331961
# total_ARTIGOS_ESPORTIVOS_F3_m4  1.158984
# FL_VAREJO_F4                    1.071612
#                                   Rank 2
# FL_PET_SHOP_F4                  0.929718
# FL_ARTIGOS_ELETRONICOS_F3       0.841047
# total_ARTIGOS_ESPORTIVOS_F1_m4  0.805795
#                                    Rank 3
# FL_BEM_ESTAR_F3                  0.726522
# CD_Cartao_6m                     0.717684
# FL_KIDS_F1                       0.675303
# FL_MATERIAL_DE_CONSTRUCAO_F1     0.669513
# FL_ENTRETENIMENTO_F1             0.657562
# FL_ARTIGOS_ELETRONICOS_F4        0.650467
# total_ARTIGOS_ELETRONICOS_F4_m4  0.611428
# FL_VIAGEM_E_TURISMO_F4           0.563414
# FL_ELETRODOMESTICO_F2            0.545371
# total_PET_SHOP_F4_m4             0.540610
#                                                   Rank 4
# FL_POSTO_DE_GASOLINA_F3                         0.468507
# NV_FC_Promessa_de_pagamento_3m                  0.462795
# FL_ENTRETENIMENTO_F3                            0.459185
# FL_EDUCACAO_F2                                  0.450474
# NV_P3_Quitacao_6m                               0.443312
# total_PET_SHOP_F3_m4                            0.440882
# total_MATERIAL_DE_CONSTRUCAO_F4_m4              0.426546
# FL_RESTAURANTE_F4                               0.420649
# total_MOVEIS_E_DECORACOES_F1_m4                 0.410563
# NV_FC_CONTATO_UTIL_3m                           0.406517
# total_VIAGEM_E_TURISMO_F3_m4                    0.400734
# FL_VIAGEM_E_TURISMO_F3                          0.397133
# total_BEM_ESTAR_F4_m4                           0.392040
# total_ARTIGOS_ELETRONICOS_F1_m4                 0.378615
# FL_PET_SHOP_F3                                  0.378251
# FL_AUTOMOVEL_F2                                 0.374331
# total_LOJAS_DE_COSMETICOS_F4_m4                 0.373457
# FL_LOJAS_DE_COSMETICOS_F2                       0.365544
# NV_BP4_Informa_o_desconto_6m                    0.365293
# total_ELETRODOMESTICO_F4_m4                     0.363015
# total_VIAGEM_E_TURISMO_F2_m4                    0.351807
# FL_VAREJO_F2                                    0.345796
# FL_AUTOMOVEL_F3                                 0.345500
# total_MOVEIS_E_DECORACOES_F2_m4                 0.341166
# total_PET_SHOP_F2_m4                            0.338265
# FL_FARMACIAS_F3                                 0.334396
# GC_AusenciaRenda_6m                             0.322863
# total_BEM_ESTAR_F2_m4                           0.322095
# NV_CX_Rechamadas_6m                             0.321854
# total_VAREJO_F4_m4                              0.320801
# total_BEM_ESTAR_F3_m4                           0.320667
# FL_ELETRODOMESTICO_F1                           0.319900
# FL_ENTRETENIMENTO_F4                            0.319445
# NV_CX_PID_6m                                    0.319123
# NV_P1_Pagamento_parcela_6m                      0.318997
# total_FARMACIAS_F4_m4                           0.308059
# FL_VESTUARIO_F4                                 0.306383
# total_LOJAS_DE_DEPARTAMENTO_F1_m4               0.305523
# FL_LOJAS_DE_COSMETICOS_F4                       0.292955
# NV_DC3_Nao_e_o_responsavel_do_financiamento_3m  0.281046
# total_KIDS_F3_m4                                0.278027
# NV_C2_GRAVACAO_DA_LIGACAO_6m                    0.273842
# FL_LOJAS_DE_COSMETICOS_F3                       0.268484
# FL_VESTUARIO_F2                                 0.265353
# total_EDUCACAO_F1_m4                            0.259681
# NV_BP6_Gera_urgencia_3m                         0.258686
#                                       Rank 5
# FL_POSTO_DE_GASOLINA_F2             0.246295
# FL_ELETRODOMESTICO_F3               0.244345
# total_EDUCACAO_F3_m4                0.242018
# PL_Sem_Condicoes_6m                 0.232538
# total_VESTUARIO_F2_m4               0.231151
# total_FARMACIAS_F1_m4               0.227626
# total_LOJAS_DE_COSMETICOS_F1_m4     0.225308
# total_LOJAS_DE_COSMETICOS_F2_m4     0.223037
# GC_IsencaoMoraMulta_3m              0.221596
# FL_VAREJO_F1                        0.221434
# CX_Cancelamento_6m                  0.220282
# FL_ENTRETENIMENTO_F2                0.219647
# FL_MATERIAL_DE_CONSTRUCAO_F3        0.217195
# FL_POSTO_DE_GASOLINA_F1             0.216741
# P6_RENEGPEDEC_6m                    0.216040
# total_AUTOMOVEL_F4_m4               0.210964
# FL_RESTAURANTE_F3                   0.210721
# FL_PET_SHOP_F2                      0.208049
# total_VESTUARIO_F3_m4               0.202221
# Produto_Veiculo_3m                  0.198696
# GC_OfertaNegociacao_6m              0.197207
# CD_Cartao_3m                        0.194664
# MOT_Informacao_6m                   0.188642
# FL_BEM_ESTAR_F1                     0.188291
# MOT_Servicos_6m                     0.185711
# NV_C2_GRAVACAO_DA_LIGACAO_3m        0.185674
# total_ELETRODOMESTICO_F3_m4         0.185432
# flmat90conta                        0.184400
# GC_IsencaoMoraMulta_6m              0.180047
# FL_AUTOMOVEL_F1                     0.177543
# FL_AUTOMOVEL_F4                     0.176234
# FL_FARMACIAS_F2                     0.174858
# FL_LOJAS_DE_DEPARTAMENTO_F3         0.174487
# CD_Seguro_6m                        0.173588
# FL_VESTUARIO_F3                     0.167598
# FL_BEM_ESTAR_F2                     0.167090
# FL_POSTO_DE_GASOLINA_F4             0.166538
# FL_RESTAURANTE_F1                   0.166055
# FL_MATERIAL_DE_CONSTRUCAO_F4        0.164814
# total_MATERIAL_DE_CONSTRUCAO_F2_m4  0.163886
# Produto_Veiculo_6m                  0.162020
# FL_ARTIGOS_ELETRONICOS_F2           0.156003
# total_FARMACIAS_F2_m4               0.153777
# total_MOVEIS_E_DECORACOES_F3_m4     0.152382
# FL_VIAGEM_E_TURISMO_F2              0.151548
# total_POSTO_DE_GASOLINA_F4_m4       0.150334
#                                      Rank 6
# total_ENTRETENIMENTO_F3_m4         0.148545
# total_AUTOMOVEL_F3_m4              0.147264
# total_LOJAS_DE_DEPARTAMENTO_F4_m4  0.145618
# total_VAREJO_F3_m4                 0.145056
# flmat60conta                       0.143578
# ...                                     ...
# FL_FARMACIAS_F4                    0.003701
# flmau60conta                       0.003605
# total_LOJAS_DE_COSMETICOS_F3_m4    0.003401
# GC_AusenciaRenda_3m                0.002638
# FL_LOJAS_DE_DEPARTAMENTO_F2        0.002464
#
# [107 rows x 1 columns]
